# %%
import os
os.getcwd()
# Out:
# 'D:\\Stock-Trend-Trading-System\\notebooks'

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
ticker = "TCS.NS"
start_date = "2018-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

df = yf.download(ticker, start=start_date, end=end_date)
df.head()
# Out:
# C:\Users\Apurk\AppData\Local\Temp\ipykernel_13840\31694961.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2018-01-01  1103.473267  1123.994445  1099.051992  1118.780726  1351760
# 2018-01-02  1097.466919  1113.483524  1092.878846  1109.479347  1920290
# 2018-01-03  1100.574219  1113.233168  1097.466863  1097.800561  1257120
# 2018-01-04  1108.269897  1110.313635  1101.137489  1105.308464   913082
# 2018-01-05  1121.658569  1125.954694  1105.308368  1105.308368  1153706

# %%
df.to_csv("../data/raw/TCS_raw.csv")
print("Data saved successfully")
# Out:
# Data saved successfully

# %%
df.shape
# Out:
# (1970, 5)
